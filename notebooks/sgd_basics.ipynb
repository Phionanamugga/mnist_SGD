# %% [markdown]
# Understanding the problem

# %% [markdown]
# Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # ✅ Define a Simple Quadratic Function (Loss Function)
# # f(x) = x^2 + 3x + 2 (Example function to minimize)#

# %%
def function(x):
    return x**2 + 3*x + 2

# %% [markdown]
# # ✅ Compute Gradient of the Function
# # f'(x) = 2x + 3

# %%
def gradient(x):
    return 2*x + 3

# %% [markdown]
# # ✅ Implement Stochastic Gradient Descent (SGD) from Scratch

# %%
def stochastic_gradient_descent(learning_rate=0.1, epochs=20):
    x = np.random.uniform(-10, 10)
    x_values = [x] 
    y_values = [function(x)] 
    
    for i in range(epochs):
        grad = gradient(x)  
        x = x - learning_rate * grad  
        x_values.append(x)
        y_values.append(function(x))
        
        print(f"Epoch {i+1}: x = {x:.4f}, f(x) = {function(x):.4f}, Gradient = {grad:.4f}")
    
    return x_values, y_values

# %% [markdown]
# # ✅ Run SGD and Collect Results

# %%
learning_rate = 0.1
epochs = 20
x_sgd, y_sgd = stochastic_gradient_descent(learning_rate, epochs)
# Out:
# Epoch 1: x = -6.8022, f(x) = 27.8632, Gradient = -13.2555
# Epoch 2: x = -5.7417, f(x) = 17.7424, Gradient = -10.6044
# Epoch 3: x = -4.8934, f(x) = 11.2652, Gradient = -8.4835
# Epoch 4: x = -4.2147, f(x) = 7.1197, Gradient = -6.7868
# Epoch 5: x = -3.6718, f(x) = 4.4666, Gradient = -5.4294
# Epoch 6: x = -3.2374, f(x) = 2.7686, Gradient = -4.3436
# Epoch 7: x = -2.8899, f(x) = 1.6819, Gradient = -3.4748
# Epoch 8: x = -2.6119, f(x) = 0.9864, Gradient = -2.7799
# Epoch 9: x = -2.3896, f(x) = 0.5413, Gradient = -2.2239
# Epoch 10: x = -2.2116, f(x) = 0.2564, Gradient = -1.7791
# Epoch 11: x = -2.0693, f(x) = 0.0741, Gradient = -1.4233
# Epoch 12: x = -1.9555, f(x) = -0.0426, Gradient = -1.1386
# Epoch 13: x = -1.8644, f(x) = -0.1172, Gradient = -0.9109
# Epoch 14: x = -1.7915, f(x) = -0.1650, Gradient = -0.7287
# Epoch 15: x = -1.7332, f(x) = -0.1956, Gradient = -0.5830
# Epoch 16: x = -1.6866, f(x) = -0.2152, Gradient = -0.4664
# Epoch 17: x = -1.6492, f(x) = -0.2277, Gradient = -0.3731
# Epoch 18: x = -1.6194, f(x) = -0.2357, Gradient = -0.2985
# Epoch 19: x = -1.5955, f(x) = -0.2409, Gradient = -0.2388
# Epoch 20: x = -1.5764, f(x) = -0.2442, Gradient = -0.1910
